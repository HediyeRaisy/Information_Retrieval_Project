# %%
import requests
from bs4 import BeautifulSoup

r = requests.get('https://www.alluniversity.info/world-top-100/')
# Create an object to parse the HTML format
soup = BeautifulSoup(r.content, 'html.parser')

data = soup.findAll('ul',attrs={'class':'top-list defer'})
link = []
for div in data:
    links = div.findAll('a')
    for a in links:
        link.append('https://www.alluniversity.info'+a['href'])

# %%
link
# Out:
# ['https://www.alluniversity.info/united-states/massachusetts-institute-of-technology/',
#  'https://www.alluniversity.info/united-kingdom/university-of-cambridge/',
#  'https://www.alluniversity.info/united-states/stanford-university/',
#  'https://www.alluniversity.info/united-kingdom/university-of-oxford/',
#  'https://www.alluniversity.info/united-states/harvard-university/',
#  'https://www.alluniversity.info/united-states/california-institute-of-technology/',
#  'https://www.alluniversity.info/united-kingdom/imperial-college-london/',
#  'https://www.alluniversity.info/united-kingdom/university-college-london/',
#  'https://www.alluniversity.info/switzerland/swiss-federal-institute-of-technology-zurich/',
#  'https://www.alluniversity.info/united-states/university-of-chicago/',
#  'https://www.alluniversity.info/singapore/national-university-of-singapore/',
#  'https://www.alluniversity.info/china/peking-university/',
# ...

# %%
documents = []
for i in range(0,100):
    # Make a request to the link
    r = requests.get(link[i])
  
    # Initialize BeautifulSoup object to parse the content 
    soup = BeautifulSoup(r.content, 'html.parser')
    # Retrieve all paragraphs and combine it as one
    sen = []
    for i in soup.find('div', {'class':'slide-text'}).find_all('p'):
        sen.append(i.text)
    # Add the combined paragraphs to documents
    documents.append(' '.join(sen))
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...

# %%
len(documents)
# Out:
# 15

# %%
documents[1]
# Out:
# 'The University of Cambridge, usually simply referred to as Cambridge, is located in Cambridge, England. It is the world’s third-oldest university. It has much in common with Oxford, having been developed by scholars who renounced Oxford following a falling-out with some of the local townspeople. Cambridge is made up of 31 colleges and more than 150 departments. The university originally emphasized mathematics and mathematical physics. It now offers a comprehensive academic program, with some colleges emphasizing specific subjects. The Institute of Continuing Education offers part-time study.'

# %%
import re
import string
documents_clean = []
for d in documents:
    # Remove Unicode
    document_test = re.sub(r'[^\x00-\x7F]+', ' ', d)
    # Remove Mentions
    document_test = re.sub(r'@\w+', '', document_test)
    # Lowercase the document
    document_test = document_test.lower()
    # Remove punctuations
    document_test = re.sub(r'[%s]' % re.escape(string.punctuation), ' ', document_test)
    # Lowercase the numbers
    document_test = re.sub(r'[0-9]', '', document_test)
    # Remove the doubled space
    document_test = re.sub(r'\s{2,}', ' ', document_test)
    documents_clean.append(document_test)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
# Instantiate a TfidfVectorizer object
vectorizer = TfidfVectorizer()
# It fits the data and transform it as a vector
X = vectorizer.fit_transform(documents_clean)
# Convert the X as transposed matrix
X = X.T.toarray()
# Create a DataFrame and set the vocabulary as the index
df = pd.DataFrame(X, index=vectorizer.get_feature_names())
# Out:
# /Users/hediyeraisy/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
df
# Out:
#                     0         1         2    3    4         5         6   \
# about         0.115858  0.000000  0.000000  0.0  0.0  0.000000  0.000000
# academic      0.074525  0.077828  0.066393  0.0  0.0  0.073039  0.000000
# accepted      0.000000  0.000000  0.000000  0.0  0.0  0.000000  0.000000
# accepting     0.000000  0.000000  0.000000  0.0  0.0  0.000000  0.126048
# acknowledged  0.000000  0.000000  0.000000  0.0  0.0  0.000000  0.000000
# ...                ...       ...       ...  ...  ...       ...       ...
# would         0.000000  0.000000  0.000000  0.0  0.0  0.000000  0.000000
# xu            0.000000  0.000000  0.000000  0.0  0.0  0.000000  0.000000
# year          0.100603  0.000000  0.000000  0.0  0.0  0.098598  0.000000
# years         0.000000  0.000000  0.000000  0.0  0.0  0.000000  0.126048
# zurich        0.000000  0.000000  0.000000  0.0  0.0  0.000000  0.000000
#
#                     7         8         9         10        11   12        13  \
# ...

# %%
import numpy as np
def get_similar_articles(q, df):
    print("query:", q)
    print("Here are the articles with the highest cosine similarity values: ")
    q = [q]
    q_vec = vectorizer.transform(q).toarray().reshape(df.shape[0],)
    sim = {}
    for i in range(10):
        sim[i] = np.dot(df.loc[:, i].values, q_vec) / np.linalg.norm(df.loc[:, i]) * np.linalg.norm(q_vec)

    sim_sorted = sorted(sim.items(), key=lambda x: x[1], reverse=True)

    for k, v in sim_sorted:
        if v != 0.0:
            print("Similarity Value:", v)
            print(documents_clean[k])
            print()

# %%
q1 = 'Harvard'
get_similar_articles(q1, df)
print('-'*100)
# Out:
# query: Harvard
# Here are the articles with the highest cosine similarity values:
# Similarity Value: 0.357121564317168
# harvard university is located in cambridge massachusetts it is the oldest university in the united states having been founded in harvard has a reputation for being one of the most prestigious institutes of higher learning in the world harvard was founded in it offers doctoral programs in biology and biological sciences classics american studies and african studies masters programs are offered in anthropology architecture american studies african studies and administration undergraduate degrees are also offered in the fields of arts and sciences
#
# ----------------------------------------------------------------------------------------------------

# %%
q2 = 'University of Cambridge'
get_similar_articles(q1, df)
print('-'*100)
# Out:
# query: Harvard
# Here are the articles with the highest cosine similarity values:
# Similarity Value: 0.357121564317168
# harvard university is located in cambridge massachusetts it is the oldest university in the united states having been founded in harvard has a reputation for being one of the most prestigious institutes of higher learning in the world harvard was founded in it offers doctoral programs in biology and biological sciences classics american studies and african studies masters programs are offered in anthropology architecture american studies african studies and administration undergraduate degrees are also offered in the fields of arts and sciences
#
# ----------------------------------------------------------------------------------------------------

# %%
q2 = 'University of Cambridge'
get_similar_articles(q2, df)
print('-'*100)
# Out:
# query: University of Cambridge
# Here are the articles with the highest cosine similarity values:
# Similarity Value: 0.4299122138000367
# the university of cambridge usually simply referred to as cambridge is located in cambridge england it is the world s third oldest university it has much in common with oxford having been developed by scholars who renounced oxford following a falling out with some of the local townspeople cambridge is made up of colleges and more than departments the university originally emphasized mathematics and mathematical physics it now offers a comprehensive academic program with some colleges emphasizing specific subjects the institute of continuing education offers part time study
#
# Similarity Value: 0.1583028922035561
# ...
